# %%
import os

import scipy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.style.use("ggplot")

COLOR = "red"
ALPHA_MEAN = 0.9
ALPHA_STD = 0.1
AVG_FILTER_SIZE = 10

# %%
def load_data(env_id: str) -> pd.DataFrame:
    files = [x for x in os.listdir() if env_id in x and x.endswith(".csv")]
    dfs = [pd.read_csv(f) for f in files]
    
    df_out = pd.DataFrame() 
    df_out["t"] = dfs[0]["t"]

    stacked_means = pd.concat([df["average_return"] for df in dfs], axis=1)
    df_out["average_return"] = stacked_means.mean(axis=1)  
    df_out["std_return"] = stacked_means.std(axis=1, ddof=1)  

    return df_out

# %% [markdown]
# ## Humanoid-v5

# %%
data = load_data("Humanoid-v5")
data.head()
# Out:
#        t  average_return  std_return
# 0   5000      224.478322   71.209019
# 1  10000      214.564158   49.835494
# 2  15000      194.620483  144.509779
# 3  20000      227.275152   15.737988
# 4  25000      313.158295   17.279589

# %%
t = data["t"]
mean = data["average_return"]
mean = scipy.ndimage.median_filter(data["average_return"], size=AVG_FILTER_SIZE)
std = data["std_return"]
lower = mean - std
upper = mean + std

fig, ax = plt.subplots()
ax.plot(t, mean, color=COLOR, alpha=ALPHA_MEAN)
ax.fill_between(t, lower, upper, alpha=ALPHA_STD, color=COLOR)
ax.set_xlabel("Time steps (1e-6)")
ax.set_ylabel("Average Return")
plt.show()

# %% [markdown]
# ## HalfCheetah-v5

# %%
data = load_data("HalfCheetah-v5")
data.head()
# Out:
#        t  average_return  std_return
# 0   5000     -406.222610  161.574723
# 1  10000     -273.758097  303.632662
# 2  15000      596.064341  382.142937
# 3  20000     1036.232564  388.642687
# 4  25000     1755.256592  544.048006

# %%
t = data["t"]
mean = data["average_return"]
mean = scipy.ndimage.median_filter(data["average_return"], size=AVG_FILTER_SIZE)
std = data["std_return"]
lower = mean - std
upper = mean + std

fig, ax = plt.subplots()
ax.plot(t, mean, color=COLOR, alpha=ALPHA_MEAN)
ax.fill_between(t, lower, upper, alpha=ALPHA_STD, color=COLOR)
ax.set_xlabel("Time steps (1e-6)")
ax.set_ylabel("Average Return")
plt.show()

# %% [markdown]
# ## Ant-v5

# %%
data = load_data("Ant-v5")
data.head()
# Out:
#        t  average_return  std_return
# 0   5000      649.975505  155.614679
# 1  10000      507.802602  118.402292
# 2  15000      339.250854   26.514519
# 3  20000      274.929718    3.792303
# 4  25000      404.618958   74.789900

# %%
t = data["t"]
mean = scipy.ndimage.median_filter(data["average_return"], size=AVG_FILTER_SIZE)
std = data["std_return"]
lower = mean - std
upper = mean + std

fig, ax = plt.subplots()
ax.plot(t, mean, color="red", alpha=0.8)
ax.fill_between(t, lower, upper, alpha=0.1, color="red")
ax.set_xlabel("Time steps (1e-6)")
ax.set_ylabel("Average Return")
plt.show()

# %% [markdown]
# ## Walker2d-v5

# %%
data = load_data("Walker2d-v5")
data.head()
# Out:
#        t  average_return  std_return
# 0   5000      116.583951  192.793914
# 1  10000      247.116592   44.179448
# 2  15000      292.814311   69.393627
# 3  20000      195.999919  106.412239
# 4  25000      277.080551   28.942436

# %%
t = data["t"]
mean = data["average_return"]
mean = scipy.ndimage.median_filter(data["average_return"], size=AVG_FILTER_SIZE)
std = data["std_return"]
lower = mean - std
upper = mean + std

fig, ax = plt.subplots()
ax.plot(t, mean, color="red", alpha=0.8)
ax.fill_between(t, lower, upper, alpha=0.1, color="red")
ax.set_xlabel("Time steps (1e-6)")
ax.set_ylabel("Average Return")
plt.show()

# %% [markdown]
# ## Hopper-v5

# %%
data = load_data("Hopper-v5")
data.head()
# Out:
#        t  average_return  std_return
# 0   5000      159.632304   23.198561
# 1  10000      203.703623   17.841621
# 2  15000      242.090841   84.869581
# 3  20000      252.631490   68.435473
# 4  25000      245.780609   64.830040

# %%
t = data["t"]
mean = data["average_return"]
mean = scipy.ndimage.median_filter(data["average_return"], size=AVG_FILTER_SIZE)
std = data["std_return"]
lower = mean - std
upper = mean + std

fig, ax = plt.subplots()
ax.plot(t, mean, color="red", alpha=0.8)
ax.fill_between(t, lower, upper, alpha=0.1, color="red")
ax.set_xlabel("Time steps (1e-6)")
ax.set_ylabel("Average Return")
plt.show()
